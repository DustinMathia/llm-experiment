# %%
import httpx

r = httpx.get('https://httpbin.org/get')
r
# Out:
# <Response [200 OK]>

# %%
r = httpx.post('https://httpbin.org/post', data={'key': 'value'})
r
# Out:
# <Response [200 OK]>

# %% [markdown]
# This openai example doesnt work yet

# %%
import os
import asyncio
from openai import AsyncOpenAI

client = AsyncOpenAI(
    # This is the default and can be omitted
    api_key=os.environ.get("API_KEY"),
    base_url=os.environ.get("BASE_URL"),
)


async def main() -> None:
    response = await client.responses.create(
        model="gpt-4o", input="Explain disestablishmentarianism to a smart five year old."
    )
    print(response.output_text)


#asyncio.run(main())
await main()
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[12], line 5
#       2 import asyncio
#       3 from openai import AsyncOpenAI
# ----> 5 client = AsyncOpenAI(
#       6     # This is the default and can be omitted
#       7     api_key=os.environ.get("API_KEY"),
#       8     base_url=os.environ.get("BASE_URL"),
#       9 )
#      12 async def main() -> None:
#      13     response = await client.responses.create(
#      14         model="gpt-4o", input="Explain disestablishmentarianism to a smart five year old."
#      15     )
#
# File ~/UCD_RSE_stuff/llm-experiment/.pixi/envs/default/lib/python3.13/site-packages/openai/_client.py:488, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     486     api_key = os.environ.get("OPENAI_API_KEY")
#     487 if api_key is None:
# --> 488     raise OpenAIError(
#     489         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     490     )
#     491 if callable(api_key):
#     492     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %% [markdown]
# use tenacity to get 'wait-after' and wait that long

# %%
import tenacity
